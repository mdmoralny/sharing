# %% [markdown]
# <h1 style="font-size:2rem;color:blue;"> Lecture 1 Introduction

# %% [markdown]
# # Jypiter python tutorial

# %%
print("hello world")
# Out:
# hello world

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# The following viddeo will provide a short but insightful overview of how Jupyter Notebooks work, it will also guide you in the installation process.

# %%
video=YouTubeVideo("2WL-XTl2QYI")
display(video)

# %% [markdown]
#  <h1 style="font-size:3rem;color:blue;">Codes

# %% [markdown]
# <h1 style="font-size:1.5rem;color:blue;"> Example 1

# %% [markdown]
# The following code shows the effects of roundoff error

# %%
import math

1 +1e-16
# Out:
# 1.0
